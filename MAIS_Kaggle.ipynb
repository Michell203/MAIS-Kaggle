# %% [markdown]
# <a href="https://colab.research.google.com/github/Michell203/MAIS-Kaggle/blob/main/MAIS_Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
import os

# py_file_location = "/content/fashion-mnist/utils"
# sys.path.append(os.path.abspath(py_file_location))

# %%
train_images = np.load("/content/drive/MyDrive/MLData/mais-202-winter-2023/train_images.npy") #load training images
train_labels = pd.read_csv("/content/drive/MyDrive/MLData/mais-202-winter-2023/train_labels.csv")
train_labels = train_labels.drop(columns= ['ID'])
train_labels = np.array(train_labels)
train_labels = train_labels.flatten()

test_images = np.load("/content/drive/MyDrive/MLData/mais-202-winter-2023/test_images.npy")

# To visualize an image you can use the following code block:

import matplotlib.pyplot as plt

def show_image(arr):
   two_d = (np.reshape(arr, (28, 28)) * 255).astype(np.uint8)
   plt.imshow(two_d, interpolation='nearest')
   plt.show()

show_image(train_images[0]) # 0 is the index of the training image you want to display
train_labels
# Out:
# array([6, 4, 6, ..., 7, 3, 2])

# %%
# !git clone https://github.com/zalandoresearch/fashion-mnist.git
# Out:
# Cloning into 'fashion-mnist'...
# remote: Enumerating objects: 762, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 762 (delta 0), reused 3 (delta 0), pack-reused 758
# Receiving objects: 100% (762/762), 105.85 MiB | 33.51 MiB/s, done.
# Resolving deltas: 100% (444/444), done.

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# import mnist_reader
# X_train, y_train = mnist_reader.load_mnist('/content/fashion-mnist/data/fashion', kind='train')
# X_test, y_test = mnist_reader.load_mnist('/content/fashion-mnist/data/fashion', kind='t10k')

# X_train = X_train.reshape((60000,28,28))
# y_train = y_train.reshape((60000,28,28))
# X_test = X_test.reshape((60000,28,28))
# y_test = y_test.reshape((60000,28,28))
# Out:
# (50000, 28, 28)

# %%
# fashion_mnist = tf.keras.datasets.fashion_mnist

# (train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# train_images.shape
# Out:
# (60000, 28, 28)

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
#Normalize pixel values
train_images = train_images / 255
test_images = test_images / 255

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    # plt.xlabel(class_names[y_train[i]])
plt.show()
